# %%
import pandas as pd

# %%
df =pd.read_excel("current_projects_as_at_31_March_2014.xlsx",skiprows=1,parse_date=["Date of OJEU"])

# %%
df.head(50)
# Out:
#     Unique HMT Project ID                                       Project Name  \
# 0                       2                              Sunningdale Park Site
# 1                       3                                            Compass
# 2                       5                              RRS Ernest Shackleton
# 3                       7  Barking & Dagenham - Two Schools Project Jo Ri...
# 4                       8                               Barnsley Schools PFI
# 5                       9             Mid-Bedfordshire Upper Schools Project
# 6                      10                         Birmingham Group Schools 1
# 7                      11                         Birmingham Group Schools 2
# 8                      12                         Castle Hill Primary School
# 9                      13      Hadley Learning Centre and Jigsaw Project PFI
# 10                     14                                        Bristol BSF
# ...

# %%
#missing value
#df.fillna(0) put 0 in all coulumn 
df.fillna({"Equity Holder 4: Name":"Bristol City Council"})
# Out:
#      Unique HMT Project ID                                       Project Name  \
# 0                        2                              Sunningdale Park Site
# 1                        3                                            Compass
# 2                        5                              RRS Ernest Shackleton
# 3                        7  Barking & Dagenham - Two Schools Project Jo Ri...
# 4                        8                               Barnsley Schools PFI
# 5                        9             Mid-Bedfordshire Upper Schools Project
# 6                       10                         Birmingham Group Schools 1
# 7                       11                         Birmingham Group Schools 2
# 8                       12                         Castle Hill Primary School
# 9                       13      Hadley Learning Centre and Jigsaw Project PFI
# 10                      14                                        Bristol BSF
# ...

# %%
df.fillna(method="ffill")#forward fill
df.fillna(method="bfill")#backward fill
# Out:
#      Unique HMT Project ID                                       Project Name  \
# 0                        2                              Sunningdale Park Site
# 1                        3                                            Compass
# 2                        5                              RRS Ernest Shackleton
# 3                        7  Barking & Dagenham - Two Schools Project Jo Ri...
# 4                        8                               Barnsley Schools PFI
# 5                        9             Mid-Bedfordshire Upper Schools Project
# 6                       10                         Birmingham Group Schools 1
# 7                       11                         Birmingham Group Schools 2
# 8                       12                         Castle Hill Primary School
# 9                       13      Hadley Learning Centre and Jigsaw Project PFI
# 10                      14                                        Bristol BSF
# ...

# %%
df.dropna(how="all")#df.dropna(thres=2)
# Out:
#      Unique HMT Project ID                                       Project Name  \
# 0                        2                              Sunningdale Park Site
# 1                        3                                            Compass
# 2                        5                              RRS Ernest Shackleton
# 3                        7  Barking & Dagenham - Two Schools Project Jo Ri...
# 4                        8                               Barnsley Schools PFI
# 5                        9             Mid-Bedfordshire Upper Schools Project
# 6                       10                         Birmingham Group Schools 1
# 7                       11                         Birmingham Group Schools 2
# 8                       12                         Castle Hill Primary School
# 9                       13      Hadley Learning Centre and Jigsaw Project PFI
# 10                      14                                        Bristol BSF
# ...

# %%
import numpy as np
df.replace(["Data not supplied","Data not provided"],np.NaN)
# Out:
#      Unique HMT Project ID                                       Project Name  \
# 0                        2                              Sunningdale Park Site
# 1                        3                                            Compass
# 2                        5                              RRS Ernest Shackleton
# 3                        7  Barking & Dagenham - Two Schools Project Jo Ri...
# 4                        8                               Barnsley Schools PFI
# 5                        9             Mid-Bedfordshire Upper Schools Project
# 6                       10                         Birmingham Group Schools 1
# 7                       11                         Birmingham Group Schools 2
# 8                       12                         Castle Hill Primary School
# 9                       13      Hadley Learning Centre and Jigsaw Project PFI
# 10                      14                                        Bristol BSF
# ...

# %%
df.interpolate()
# Out:
#      Unique HMT Project ID                                       Project Name  \
# 0                        2                              Sunningdale Park Site
# 1                        3                                            Compass
# 2                        5                              RRS Ernest Shackleton
# 3                        7  Barking & Dagenham - Two Schools Project Jo Ri...
# 4                        8                               Barnsley Schools PFI
# 5                        9             Mid-Bedfordshire Upper Schools Project
# 6                       10                         Birmingham Group Schools 1
# 7                       11                         Birmingham Group Schools 2
# 8                       12                         Castle Hill Primary School
# 9                       13      Hadley Learning Centre and Jigsaw Project PFI
# 10                      14                                        Bristol BSF
# ...

# %%
g=df.groupby("Region")
for r,r_f in g:
    print(g)
    print(r_f)
# Out:
# ...
#     Unique HMT Project ID  Project Name                        Department  \
# 51                     57  Lewisham BSF  DEPARTMENT FOR EDUCATION (GROUP)
#
#    Procuring Authority         Sector       Constituency             Region  \
# 51            Lewisham  Schools (BSF)  Data not provided  Data not provided
#
#    Project Status         Date of OJEU Date of Prefered Bidder  \
# 51    InOperation  2005-04-22 00:00:00       Data not provided
#
#           ...         Equity Holder 3: Equity Share (%)  \
# 51        ...                                       0.4
#
#          Equity Holder 4: Name Equity Holder 4: Equity Share (%)  \
# 51  London Borough of Lewisham                               0.1
#
#     Equity Holder 5: Name Equity Holder 5: Equity Share (%)  \
# 51                    NaN                               0.0
#
#    Equity Holder 6: Name Equity Holder 6: Equity Share (%)           SPV Name  \
# ...
