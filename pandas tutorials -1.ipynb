# %%
import pandas as pd

# %%
#read data from csv file
df = pd.read_csv('weather_data_nyc_centralpark_2016.csv')

# %%
#all rows
df
# Out:
#        1-1-2016  42  34  38.0  0.00   0.0   0
# 0      2-1-2016  40  32  36.0  0.00   0.0   0
# 1      3-1-2016  45  35  40.0  0.00   0.0   0
# 2      4-1-2016  36  14  25.0  0.00   0.0   0
# 3      5-1-2016  29  11  20.0  0.00   0.0   0
# 4      6-1-2016  41  25  33.0  0.00   0.0   0
# 5      7-1-2016  46  31  38.5  0.00   0.0   0
# 6      8-1-2016  46  31  38.5  0.00   0.0   0
# 7      9-1-2016  47  40  43.5     T   0.0   0
# 8     10-1-2016  59  40  49.5  1.80   0.0   0
# 9     11-1-2016  40  26  33.0  0.00   0.0   0
# 10    12-1-2016  44  25  34.5  0.00     T   0
# 11    13-1-2016  30  22  26.0  0.00   0.0   0
# 12    14-1-2016  38  22  30.0  0.00     T   0
# 13    15-1-2016  51  34  42.5     T   0.0   0
# 14    16-1-2016  52  42  47.0  0.24   0.0   0
# 15    17-1-2016  42  30  36.0  0.05   0.4   0
# 16    18-1-2016  31  18  24.5     T     T   T
# 17    19-1-2016  28  16  22.0  0.00   0.0   T
# 18    20-1-2016  37  27  32.0  0.00   0.0   T
# ...

# %%
'''first five rows by default'''
df.head()
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 0  1-1-2016                   42                   34                 38.0
# 1  2-1-2016                   40                   32                 36.0
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
#
#   precipitation snow fall snow depth
# 0          0.00       0.0          0
# 1          0.00       0.0          0
# 2          0.00       0.0          0
# 3          0.00       0.0          0
# 4          0.00       0.0          0

# %%
'''last five rows'''
df.tail()
# Out:
#            date  maximum temperature  minimum temperature  \
# 361  27-12-2016                   60                   40
# 362  28-12-2016                   40                   34
# 363  29-12-2016                   46                   33
# 364  30-12-2016                   40                   33
# 365  31-12-2016                   44                   31
#
#      average temperature precipitation snow fall snow depth
# 361                 50.0             0         0          0
# 362                 37.0             0         0          0
# 363                 39.5          0.39         0          0
# 364                 36.5          0.01         T          0
# 365                 37.5             0         0          0

# %%
#max value in maximum temperature
df["maximum temperature"].max()
# Out:
# 96

# %%
#in which date average temperature is 37
df["date"][df["average temperature"]==37.0]
# Out:
# 27      28-1-2016
# 47      17-2-2016
# 94       4-4-2016
# 362    28-12-2016
# Name: date, dtype: object

# %%
#average maximum temperature
df["maximum temperature"].mean()
# Out:
# 64.6256830601093

# %%
#inplace NaN value use
df.fillna(0,inplace=True)

# %%
#find row and column
rows,column=df.shape
print(rows,"and",column)
# Out:
# 366 and 7

# %%
#acees dataframe with index
df[1:5]
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 1  2-1-2016                   40                   32                 36.0
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
#
#   precipitation snow fall snow depth
# 1          0.00       0.0          0
# 2          0.00       0.0          0
# 3          0.00       0.0          0
# 4          0.00       0.0          0

# %%
#accessing by column name
df.date #or df["date"]
# Out:
# 0        1-1-2016
# 1        2-1-2016
# 2        3-1-2016
# 3        4-1-2016
# 4        5-1-2016
# 5        6-1-2016
# 6        7-1-2016
# 7        8-1-2016
# 8        9-1-2016
# 9       10-1-2016
# 10      11-1-2016
# 11      12-1-2016
# 12      13-1-2016
# 13      14-1-2016
# 14      15-1-2016
# 15      16-1-2016
# 16      17-1-2016
# 17      18-1-2016
# 18      19-1-2016
# 19      20-1-2016
# 20      21-1-2016
# 21      22-1-2016
# 22      23-1-2016
# 23      24-1-2016
# 24      25-1-2016
# 25      26-1-2016
# 26      27-1-2016
# 27      28-1-2016
# 28      29-1-2016
# 29      30-1-2016
#           ...
# 336     2-12-2016
# 337     3-12-2016
# 338     4-12-2016
# 339     5-12-2016
# 340     6-12-2016
# 341     7-12-2016
# 342     8-12-2016
# 343     9-12-2016
# 344    10-12-2016
# 345    11-12-2016
# 346    12-12-2016
# 347    13-12-2016
# 348    14-12-2016
# 349    15-12-2016
# 350    16-12-2016
# 351    17-12-2016
# 352    18-12-2016
# 353    19-12-2016
# 354    20-12-2016
# ...

# %%
#find column name
df.columns
# Out:
# Index(['date', 'maximum temperature', 'minimum temperature',
#        'average temperature', 'precipitation', 'snow fall', 'snow depth'],
#       dtype='object')

# %%
#find type of the column
type(df.date)
# Out:
# pandas.core.series.Series

# %%
#how many columns you like
df[["date","maximum temperature"]]
# Out:
#            date  maximum temperature
# 0      1-1-2016                   42
# 1      2-1-2016                   40
# 2      3-1-2016                   45
# 3      4-1-2016                   36
# 4      5-1-2016                   29
# 5      6-1-2016                   41
# 6      7-1-2016                   46
# 7      8-1-2016                   46
# 8      9-1-2016                   47
# 9     10-1-2016                   59
# 10    11-1-2016                   40
# 11    12-1-2016                   44
# 12    13-1-2016                   30
# 13    14-1-2016                   38
# 14    15-1-2016                   51
# 15    16-1-2016                   52
# 16    17-1-2016                   42
# 17    18-1-2016                   31
# 18    19-1-2016                   28
# 19    20-1-2016                   37
# 20    21-1-2016                   36
# 21    22-1-2016                   30
# 22    23-1-2016                   27
# 23    24-1-2016                   35
# ...

# %%
# standard deviation
df["maximum temperature"].std()
# Out:
# 18.041787004043528

# %%
# Describe the data frame
df.describe()
# Out:
#        maximum temperature  minimum temperature  average temperature
# count           366.000000           366.000000           366.000000
# mean             64.625683            49.806011            57.215847
# std              18.041787            16.570747            17.124760
# min              15.000000            -1.000000             7.000000
# 25%              50.000000            37.250000            44.000000
# 50%              64.500000            48.000000            55.750000
# 75%              81.000000            65.000000            73.500000
# max              96.000000            81.000000            88.500000

# %%
#condition on column
df[df["maximum temperature"]==df["maximum temperature"].max()]
# Out:
#           date  maximum temperature  minimum temperature  average temperature  \
# 204  23-7-2016                   96                   80                 88.0
# 225  13-8-2016                   96                   81                 88.5
#
#     precipitation snow fall snow depth
# 204             0         0          0
# 225             0         0          0

# %%
#index check
df.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
#set index  of date 
df.set_index("date")#it gives new datframe for modification df.set_index("date",inplace=True)
#df.reset_index(inplace=True)
# Out:
#             maximum temperature  minimum temperature  average temperature  \
# date
# 1-1-2016                     42                   34                 38.0
# 2-1-2016                     40                   32                 36.0
# 3-1-2016                     45                   35                 40.0
# 4-1-2016                     36                   14                 25.0
# 5-1-2016                     29                   11                 20.0
# 6-1-2016                     41                   25                 33.0
# 7-1-2016                     46                   31                 38.5
# 8-1-2016                     46                   31                 38.5
# 9-1-2016                     47                   40                 43.5
# 10-1-2016                    59                   40                 49.5
# 11-1-2016                    40                   26                 33.0
# 12-1-2016                    44                   25                 34.5
# ...

# %%
#index wise data
df.loc[0]
# Out:
# date                   1-1-2016
# maximum temperature          42
# minimum temperature          34
# average temperature          38
# precipitation              0.00
# snow fall                   0.0
# snow depth                    0
# Name: 0, dtype: object

# %%
#skip rows in csv or excel file and header and add coulumn name by your choices or rows and nan values
df2 = pd.read_csv('weather_data_nyc_centralpark_2016.csv',skiprows=1,header=None,names=[1,2,3,4,5,6],nrows=100
                  ,na_values={5:["T"],
                             4:["T"]})
df2.head()
# Out:
#            1   2     3    4    5  6
# 1-1-2016  42  34  38.0  0.0  0.0  0
# 2-1-2016  40  32  36.0  0.0  0.0  0
# 3-1-2016  45  35  40.0  0.0  0.0  0
# 4-1-2016  36  14  25.0  0.0  0.0  0
# 5-1-2016  29  11  20.0  0.0  0.0  0

# %%
#replace header 6 , T value with 5
def converter_cell(cell):
    if cell=="T":
        return 5
    return cell
df3=pd.read_csv("weather_data_nyc_centralpark_2016.csv",converters={"snow fall":converter_cell})
df3
# Out:
#            date  maximum temperature  minimum temperature  \
# 0      1-1-2016                   42                   34
# 1      2-1-2016                   40                   32
# 2      3-1-2016                   45                   35
# 3      4-1-2016                   36                   14
# 4      5-1-2016                   29                   11
# 5      6-1-2016                   41                   25
# 6      7-1-2016                   46                   31
# 7      8-1-2016                   46                   31
# 8      9-1-2016                   47                   40
# 9     10-1-2016                   59                   40
# 10    11-1-2016                   40                   26
# 11    12-1-2016                   44                   25
# 12    13-1-2016                   30                   22
# 13    14-1-2016                   38                   22
# 14    15-1-2016                   51                   34
# ...
